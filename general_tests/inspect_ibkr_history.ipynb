# %%
import pandas as pd
from pathlib import Path

df = pd.read_csv(Path.cwd().parent / "data" / "IBKR_history.csv", index_col=1)
# Out:
#                 Statement        Date Transaction Type Symbol Quantity  \
# Type
# Data  Transaction History  2026-03-16       Adjustment      -        -
# Data  Transaction History  2025-07-24             Sell   CSPX     -0.5
# Data  Transaction History  2025-07-24              Buy  LYMDd     10.0
# Data  Transaction History  2025-07-10             Sell   CSPX     -0.5
# Data  Transaction History  2025-07-10              Buy  LYMDd   0.7675
# ...                   ...         ...              ...    ...      ...
# Data  Transaction History  2023-09-12              Buy   CSPX   0.5786
# Data  Transaction History  2023-09-12              Buy   VUSA   0.2592
# Data  Transaction History  2023-09-12              Buy   VUSA      1.0
# Data  Transaction History  2023-09-12              Buy   VUSA      1.0
# Data  Transaction History  2023-09-12          Deposit      -        -
#
#         Price Price Currency  Gross Amount Commission   Net Amount
# Type
# ...

# %%
# Out:
# 0        0.013771
# 1      289.050000
# 2     -280.110000
# 3      285.360000
# 4      -22.000387
#          ...
# 74    -252.718015
# 75     -20.582813
# 76     -79.410000
# 77     -79.410000
# 78    9000.000000
# Name: Gross Amount, Length: 79, dtype: float64
# Index(['Statement', 'Type', 'Date', 'Transaction Type', 'Symbol', 'Quantity',
#        'Price', 'Price Currency', 'Gross Amount', 'Commission', 'Net Amount'],
#       dtype='object')
